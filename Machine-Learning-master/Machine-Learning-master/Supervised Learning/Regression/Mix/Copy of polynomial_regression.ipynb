# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:,1:-1].values
Y = dataset.iloc[:,-1].values

# %%
print(Y)
# Out:
# [  45000   50000   60000   80000  110000  150000  200000  300000  500000
#  1000000]

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import  LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree =4)#object of class with 4th order polynomial
X_poly= poly_reg.fit_transform(X)#turn single feature matrix into new matrix where 1st feature is x and 2nd feature is x^2
lin_reg_2=LinearRegression()#this object train the new matrix of diff features with diff power of x and salry
lin_reg_2.fit(X_poly,Y)#take features with diff power as input and fit the model
# Out:
# LinearRegression()

# %%
print(X_poly)
# Out:
# [[1.000e+00 1.000e+00 1.000e+00 1.000e+00 1.000e+00]
#  [1.000e+00 2.000e+00 4.000e+00 8.000e+00 1.600e+01]
#  [1.000e+00 3.000e+00 9.000e+00 2.700e+01 8.100e+01]
#  [1.000e+00 4.000e+00 1.600e+01 6.400e+01 2.560e+02]
#  [1.000e+00 5.000e+00 2.500e+01 1.250e+02 6.250e+02]
#  [1.000e+00 6.000e+00 3.600e+01 2.160e+02 1.296e+03]
#  [1.000e+00 7.000e+00 4.900e+01 3.430e+02 2.401e+03]
#  [1.000e+00 8.000e+00 6.400e+01 5.120e+02 4.096e+03]
#  [1.000e+00 9.000e+00 8.100e+01 7.290e+02 6.561e+03]
#  [1.000e+00 1.000e+01 1.000e+02 1.000e+03 1.000e+04]]

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X,Y, color='red')
plt.plot(X,lin_reg.predict(X), color='blue')
plt.title('Truth or Bluff (Linear Regression)',color='black')
plt.grid('on', linestyle='-')
plt.xlabel('Position level',color='green')
plt.ylabel('Salary', color= 'green')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X,Y, color='red')
plt.plot(X,lin_reg_2.predict(X_poly), color='blue')
plt.title('Truth or Bluff (Polynomial Regression)',color='black')
#plt.grid('on', linestyle='-')
plt.xlabel('Position level')
plt.ylabel('Salary', color= 'green')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
X_grid = np.arange(min(X), max(X), 0.1)#return evenly spaced values
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, Y, color = 'red')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
int(lin_reg.predict([[6.5]]))
# Out:
# 330378

# %%
int(lin_reg.predict([[7.5]]))
# Out:
# 411257

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
int(lin_reg_2.predict(poly_reg.fit_transform([[6.5]])))
# Out:
# 158862

# %%
int(lin_reg_2.predict(poly_reg.fit_transform([[7.5]])))
# Out:
# 225126
